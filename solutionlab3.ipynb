# %%
import pandas as pd  # keywords are highlighted in green, other strings in red, etc.
import numpy as np

# %%
data= pd.read_excel('marketing_customer_analysis.xlsx')
display(data.head()) #first 5 lines. note index of row is the same as a number of a row
display(data.tail())
data.shape
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
data.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data.plot.bar(x='Response') #creates a plot in pandas
data['Response'].value_counts()

#plt.show() # shows the plot to the user
# Out:
# No     7826
# Yes    1308
# Name: Response, dtype: int64

# %%
data['Response'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Show a plot of the response rate by the sales channel.

filter = (data['Sales Channel'] == 'Agent') & (data['Response']=='Yes')
agentyes = len(data[filter])
print('Agent with Yes: ', agentyes)

filter = (data['Sales Channel'] == 'Agent') & (data['Response']=='Yes') | (data['Response']=='No')
agenttotal = len(data[filter])
print('Agent Total:', agenttotal)

filter = (data['Sales Channel'] == 'Branch') & (data['Response']=='Yes')
branch = len(data[filter])
print('Branch with Yes', branch)

filter = (data['Sales Channel'] == 'Branch') & (data['Response']=='Yes')  | (data['Response']=='No')
branchtotal = len(data[filter])
print('Branch Total', branchtotal)

filter = (data['Sales Channel'] =='Call Center')& (data['Response']=='Yes')
callc = len(data[filter])
print('Call Center with Yes', callc)

filter = (data['Sales Channel'] =='Call Center')& (data['Response']=='Yes') | (data['Response']=='No')
callcentertotal = len(data[filter])
print('Call Center Total', callcentertotal)

filter = (data['Sales Channel'] =='Web')& (data['Response']=='Yes')
web = len(data[filter])
print('Web with Yes', web)

filter = (data['Sales Channel'] =='Web')& (data['Response']=='Yes') | (data['Response']=='No')
webtotal = len(data[filter])
print('Web Total', webtotal)
#Agent          3477
#Branch         2567
#Call Center    1765
#Web            1325
# Out:
# Agent with Yes:  666
# Agent Total: 8492
# Branch with Yes 294
# Branch Total 8120
# Call Center with Yes 192
# Call Center Total 8018
# Web with Yes 156
# Web Total 7982

# %%
fig, ax = plt.subplots()

channels = ['Agent', 'Branch', 'Call Center', 'Web']
counts = [agentyes/agenttotal, branch/branchtotal, callc/callcentertotal, web/webtotal]
bar_labels = ['red', 'blue', 'green', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange']

ax.bar(channels, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('Response rate')

ax.legend(title='Response rate by the sales channel')

plt.show()

# %%
#data['Total Claim Amount'].value_counts()
# We should make bars
#data['Total Claim Amount'].unique()
#minim=min(data['Total Claim Amount'].unique())
#maxim=max(data['Total Claim Amount'].unique())
#print(minim, maxim) #0.099007 2893.239678
#this is total claim amounts with yes and in range from 0 to 500
#data2 = data[(data['Total Claim Amount']<500)&(data['Total Claim Amount']>0)& (data['Response']=='Yes')]
#data2col=data2['Total Claim Amount']
#display(data2col.head())
#this is total claim amounts with yes and no and in range from 0 to 500
#data2yn = data[(data['Total Claim Amount']<500)&(data['Total Claim Amount']>0)& (data['Response']=='Yes')|(data['Response']=='No')]
#data2colyn=data2yn['Total Claim Amount']

#data3 = data[(data['Total Claim Amount']<1000)&(data['Total Claim Amount']>=501)& (data['Response']=='Yes')]
#data3col=data3['Total Claim Amount']

#data3yn = data[(data['Total Claim Amount']<1000)&(data['Total Claim Amount']>=501)& (data['Response']=='Yes')|(data['Response']=='No')]
#data3colyn=data3yn['Total Claim Amount']

#data4 = data[(data['Total Claim Amount']<1500)&(data['Total Claim Amount']>=1001)& (data['Response']=='Yes')]
#data4col=data4['Total Claim Amount']

#data4 = data[(data['Total Claim Amount']<1500)&(data['Total Claim Amount']>=1001)& (data['Response']=='Yes')|(data['Response']=='No')]
#data4colyn=data4['Total Claim Amount']

#data5 = data[(data['Total Claim Amount']<2000)&(data['Total Claim Amount']>=1501)& (data['Response']=='Yes')]
#data5col=data5['Total Claim Amount']

#data5 = data[(data['Total Claim Amount']<2000)&(data['Total Claim Amount']>=1501)& (data['Response']=='Yes')|(data['Response']=='No')]
#data5colyn=data5['Total Claim Amount']

#data6 = data[(data['Total Claim Amount']<2500)&(data['Total Claim Amount']>=2001)& (data['Response']=='Yes')]
#data7 = data[(data['Total Claim Amount']<3000)&(data['Total Claim Amount']>=2501)& (data['Response']=='Yes')]
#plt.hist((data2col/data2colyn,data3col/data3colyn,data4col/data4colyn))

# %%
data.head()
# Out:
#    level_0  index Customer       State  Customer Lifetime Value Response  \
# 0        0      0  BU79786  Washington              2763.519279       No
# 1        1      1  QZ44356     Arizona              6979.535903       No
# 2        2      2  AI49188      Nevada             12887.431650       No
# 3        3      3  WW63253  California              7645.861827       No
# 4        4      4  HB64268  Washington              2813.692575       No
#
#    Coverage Education Effective To Date EmploymentStatus  ...  \
# 0     Basic  Bachelor           2/24/11         Employed  ...
# 1  Extended  Bachelor           1/31/11       Unemployed  ...
# 2   Premium  Bachelor           2/19/11         Employed  ...
# 3     Basic  Bachelor           1/20/11       Unemployed  ...
# 4     Basic  Bachelor            2/3/11         Employed  ...
#
#   Number of Open Complaints  Number of Policies     Policy Type        Policy  \
# ...

# %%
len(data["Response"])
# Out:
# 9134

# %%
data["Response"].value_counts()/len(data)
# Out:
# No     0.856799
# Yes    0.143201
# Name: Response, dtype: float64

# %%
sns.boxplot(data = data,  x= "Total Claim Amount", y = "Response");

# %%
sns.boxplot(data = data,  x= "Income", y = "Response");
